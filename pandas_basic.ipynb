# %% [markdown]
# # Latihan Pandas Dasar
#
# Tujuan:
# - Membaca file CSV
# - Menampilkan data
# - Menampilkan informasi dataset

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

df
# Out:
#     Nama  Umur  Nilai
# 0   Andi    20     85
# 1   Budi    21     90
# 2  Citra    19     88
# 3   Dina    22     92
# 4    Eko    20     80

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print(df.head())
# Out:
#     Nama  Umur  Nilai
# 0   Andi    20     85
# 1   Budi    21     90
# 2  Citra    19     88
# 3   Dina    22     92
# 4    Eko    20     80

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    5 non-null      object
#  1   Umur    5 non-null      int64
#  2   Nilai   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes
# None

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print(df.describe())
# Out:
#             Umur      Nilai
# count   5.000000   5.000000
# mean   20.400000  87.000000
# std     1.140175   4.690416
# min    19.000000  80.000000
# 25%    20.000000  85.000000
# 50%    20.000000  88.000000
# 75%    21.000000  90.000000
# max    22.000000  92.000000

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print("Rata-rata nilai:", df['Nilai'].mean())
print("Nilai tertinggi:", df['Nilai'].max())
print("Nilai terendah:", df['Nilai'].min())
# Out:
# Rata-rata nilai: 87.0
# Nilai tertinggi: 92
# Nilai terendah: 80

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print(df[df['Nilai'] >= 90])
# Out:
#    Nama  Umur  Nilai
# 1  Budi    21     90
# 3  Dina    22     92
