# %% [markdown]
# Nilai di atas 85

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print(df[df['Nilai'] > 85])

# %% [markdown]
# Umur 20 tahun

# %%
import pandas as pd

df = pd.read_csv('mahasiswa.csv')

print(df[df['Umur'] == 20])
