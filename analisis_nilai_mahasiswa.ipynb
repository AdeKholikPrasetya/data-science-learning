# %% [markdown]
# Tugas Latihan:
#
# -Baca dataset
# -Tampilkan jumlah mahasiswa
# -Hitung rata-rata nilai
# -Cari nilai tertinggi
# -Cari nilai terendah
# -Tampilkan mahasiswa dengan nilai > 85
# -Buat grafik batang
